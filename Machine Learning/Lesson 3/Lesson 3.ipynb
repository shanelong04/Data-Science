# %%
# LESSON 3.1

import pandas as pd
df1 = pd.read_csv('mtcars.csv', delimiter = ",")
type(df1)
df1.mean()
df1.corr()
# Out:
#            mpg       cyl      disp        hp      drat        wt      qsec  \
# mpg   1.000000 -0.852162 -0.847551 -0.776168  0.681172 -0.867659  0.418684
# cyl  -0.852162  1.000000  0.902033  0.832447 -0.699938  0.782496 -0.591242
# disp -0.847551  0.902033  1.000000  0.790949 -0.710214  0.887980 -0.433698
# hp   -0.776168  0.832447  0.790949  1.000000 -0.448759  0.658748 -0.708223
# drat  0.681172 -0.699938 -0.710214 -0.448759  1.000000 -0.712441  0.091205
# wt   -0.867659  0.782496  0.887980  0.658748 -0.712441  1.000000 -0.174716
# qsec  0.418684 -0.591242 -0.433698 -0.708223  0.091205 -0.174716  1.000000
# vs    0.664039 -0.810812 -0.710416 -0.723097  0.440278 -0.554916  0.744535
# am    0.599832 -0.522607 -0.591227 -0.243204  0.712711 -0.692495 -0.229861
# gear  0.480285 -0.492687 -0.555569 -0.125704  0.699610 -0.583287 -0.212682
# carb -0.550925  0.526988  0.394977  0.749812 -0.090790  0.427606 -0.656249
#
#             vs        am      gear      carb
# ...

# %%
# LESSON 3.2
#checking for missing values and outliers within the hoursepower column
df1['hp'].isnull().any() 
import matplotlib.pyplot as plt
plt.figure()
df1.boxplot(['hp'])
# LESSON 3.3
df2 = pd.read_csv('Salaries.csv', delimiter = ',')
df2.groupby('Year').TotalPayBenefits.sum()
df2.groupby('Year')['TotalPayBenefits','EmployeeName'].agg(['count','max','min','mean'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# <ipython-input-4-b46b8f30bddb>:10: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df2.groupby('Year')['TotalPayBenefits','EmployeeName'].agg(['count','max','min','mean'])
#      TotalPayBenefits
#                 count        max     min           mean
# Year
# 2011            36158  567595.43    0.00   71743.819645
# 2012            36765  407274.78    1.91  100551.886807
# 2013            37606  425815.28  -33.89  101440.519714
# 2014            38119  510732.68 -618.13  100261.438668

# %%
# %matplotlib inline
df2.groupby('TotalPayBenefits').mean().plot(kind = 'bar') #visualization
