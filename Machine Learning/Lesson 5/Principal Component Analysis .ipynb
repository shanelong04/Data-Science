# %%
from sklearn.datasets import load_iris

# %%
data = load_iris()
x = data.data
y = data.target

# %%
from sklearn.model_selection import train_test_split 
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2, random_state = 2)
x_train.shape
# Out:
# (120, 4)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
predictions = lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test,predictions)
print(accuracy)
# Out:
# 0.9666666666666667

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 2)

# %%
x_train_transformed = pca.fit_transform(x_train)

# %%
x_train_transformed.shape
# Out:
# (120, 2)

# %%
x_test_transformed = pca.transform(x_test)
x_test_transformed
# Out:
# array([[-2.943348  , -0.14326254],
#        [-2.86575917, -0.36706601],
#        [ 1.23026155, -0.78245998],
#        [-2.90754046, -0.2780272 ],
#        [-2.47894539, -0.08858375],
#        [ 2.25896894,  0.47700821],
#        [-2.62911803, -0.18415637],
#        [ 2.19962543, -0.2307869 ],
#        [ 2.00167139, -0.20650843],
#        [-2.83583772, -0.29151302],
#        [-2.67311246,  0.53397128],
#        [-3.11751218, -0.39668405],
#        [-2.99105921,  0.02807218],
#        [-2.41259382,  0.69522444],
#        [ 0.68092046,  0.17486787],
#        [ 0.96301126,  0.07740808],
#        [-2.96363191, -0.9745221 ],
#        [ 0.2554196 , -0.3108025 ],
#        [ 2.29123499,  0.3075376 ],
#        [ 0.04957641, -0.69539903],
#        [ 1.43070974,  0.27140882],
#        [ 0.58905241,  0.14670131],
#        [ 1.77896333,  0.11666641],
#        [ 0.23839232, -0.52066005],
#        [ 0.6946473 , -0.36469833],
#        [-2.75365561, -0.24576344],
#        [-3.01133854, -0.19308558],
#        [ 1.16831952, -0.12497175],
#        [-2.33779687,  0.38551169],
#        [ 2.48409637,  0.57039521]])

# %%
lr = LogisticRegression(penalty = 'l2')

# %%
lr.fit(x_train_transformed,y_train)
# Out:
# LogisticRegression()

# %%
predictions = lr.predict(x_test_transformed)
accuracy = accuracy_score(y_test,predictions)
accuracy
# Out:
# 0.9666666666666667
